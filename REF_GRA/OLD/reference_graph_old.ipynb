# %%
import networkx as nx
import pandas as pd

# %%
# Load dataset
DIR = "./DATA/enerpol_full.pickle"
df = pd.read_pickle(DIR)

# %%
# Dataset info
# Filter no references

df = df[df["References"] != "no_references"]
df = df[df["Authors"] != "no_author"]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 828 entries, 0 to 10
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Title                     828 non-null    object
#  1   Authors_and_Affiliations  828 non-null    object
#  2   Affiliations              828 non-null    object
#  3   DOI                       828 non-null    object
#  4   Authors                   828 non-null    object
#  5   Journal                   828 non-null    object
#  6   Date                      828 non-null    object
#  7   Subjects                  828 non-null    object
#  8   Abstract                  828 non-null    object
#  9   References                828 non-null    object
#  10  Content                   828 non-null    object
#  11  Keywords                  828 non-null    object
#  12  Style                     828 non-null    int64
# dtypes: int64(1), object(12)
# memory usage: 90.6+ KB

# %%
print(df["Authors"].sample(1).tolist()[0])
for a in df["DOI"].sample(1).tolist()[0]:
    print(a)
# Out:
# Temoltzin-Loranca, Yunuén and Gobet, Erika and Vannière, Boris and van Leeuwen, Jacqueline F.N. and Wienhues, Giulia and Courtney-Mustaphi, Colin and Kishe, Mary and Muschick, Moritz and King, Leighton and Misra, Pavani and Ngoepe, Nare and Matthews, Blake and Vogel, Hendrik and Heiri, Oliver and Seehausen, Ole and Grosjean, Martin and Tinner, Willy
# 10.1016/j.enpol.2008.06.007

# %%
DOI_list = [a[0][1:] for a in df["DOI"].tolist()]

# %%
print(len(DOI_list))
# Out:
# 828

# %%
from pyvis.network import Network
from time import time

def pyvis_show(graf, phi=False, name="Default"):
    net = Network()
    net.from_nx(graf)
    net.toggle_physics(phi)
    net.show("{}_{}.html".format(name, time()))

# %%
# Get multiple at once

import matplotlib.pyplot as plt
import networkx as nx

from semanticscholar import SemanticScholar
sch = SemanticScholar()
list_of_paper_ids = DOI_list[0:500]
results = sch.get_papers(list_of_paper_ids)

# Create a graph
G = nx.Graph()
for item in results:
    authors = [author['name'] for author in item.authors]
    for i, author1 in enumerate(authors):
        for j, author2 in enumerate(authors):
            if i != j:
                G.add_edge(author1, author2)

# # Plot the graph
# pyvis_show(G, True)



import networkx as nx
from itertools import combinations
from tqdm import tqdm


print("Stvaranje grafa: ")
G = nx.Graph()
for line in tqdm(hashes):
    temp = list(combinations(set(line), 2))
    for comb in temp:
        comb = (remove_emoji(comb[0]), remove_emoji(comb[1]))
        if G.has_edge(comb[0], comb[1]):
            G[comb[0]][comb[1]]['weight'] += 1
        elif G.has_edge(comb[1], comb[0]):
            G[comb[1]][comb[0]]['weight'] += 1
        else:
            G.add_edge(comb[0], comb[1], weight=1)

largest_cc = max(nx.connected_components(G), key=len)
S = G.subgraph(largest_cc).copy()

print_graph_info(G)
print_graph_info(S)

# # Graf save
# pickle.dump(G, open('graph_pro14.pickle', 'wb'))
# pickle.dump(S, open('largest_cc_pro14.pickle', 'wb'))
# with open('largest_cc_pro14.txt', 'w') as f:
#     f.writelines(largest_cc)

print("Crtanje ...")
pyvis_show(S, True)
# Out:
# Stvaranje grafa:
# /home/p0l3/.local/lib/python3.10/site-packages/semanticscholar/AsyncSemanticScholar.py:193: UserWarning: IDs not found: ['10.1016/j.enpol.2019.111101', '10.1016/j.enpol.2023.113588', '10.1016/j.enpol.2018.11.044', 'o_doi', '10.1016/j.enpol.2017.04.011', '10.1016/j.enpol.2023.113724', '10.1016/j.enpol.2021.112728', '10.1016/j.enpol.2020.111941', '10.1016/j.enpol.2021.112435', '10.1016/j.enpol.2013.06.107', '10.1016/j.enpol.2019.111047', 'o_doi', '10.1016/j.enpol.2022.112980', '0.1016/j.enpol.2006.12.001', '10.1016/j.enpol.2021.112567', '0.1016/j.enpol.2008.09.030', '10.1016/j.enpol.2022.113133', '0.1016/j.enpol.2009.02.006', '10.1016/j.enpol.2012.04.027', '10.1016/j.enpol.2023.113442', '0.1016/j.enpol.2006.02.010', '10.1016/j.enpol.2023.113649', '0.1016/j.enpol.2008.09.058', '10.1016/j.enpol.2023.113575', '10.1016/j.enpol.2023.113536', '10.1016/j.enpol.2018.10.054', 'o_doi', '10.1016/j.enpol.2023.113466', '10.1016/j.enpol.2023.113545', '0.1016/j.enpol.2008.09.027', '10.1016/j.enpol.2023.113549', '0.1016/j.enpol.2008.06.006', 'o_doi', '10.1016/j.enpol.2022.113386', '10.1016/j.enpol.2022.113278', '10.1016/j.enpol.2022.113344', '0.1016/j.enpol.2006.12.013', '10.1016/j.enpol.2022.113080', '10.1016/j.enpol.2022.113151', '10.1016/j.enpol.2022.112915', '10.1016/j.enpol.2021.112291', 'o_doi', 'o_doi', '10.1016/j.enpol.2022.112989', '10.1016/j.enpol.2023.113634', '0.1016/j.enpol.2006.10.018', '10.1016/j.enpol.2022.113382', '10.1016/j.enpol.2023.113620', '10.1016/j.enpol.2023.113828', '10.1016/j.enpol.2023.113727', '0.1016/j.enpol.2006.12.012', 'o_doi', '10.1016/j.enpol.2022.112801', '10.1016/j.enpol.2023.113581', '10.1016/j.enpol.2023.113528', '0.1016/j.enpol.2006.06.005', '10.1016/j.enpol.2022.113055', '10.1016/j.enpol.2022.112794', '10.1016/j.enpol.2022.113262']
#   warnings.warn(f"IDs not found: {not_found_ids}")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 32
#      30 print("Stvaranje grafa: ")
#      31 G = nx.Graph()
# ---> 32 for line in tqdm(hashes):
#      33     temp = list(combinations(set(line), 2))
#      34     for comb in temp:
#
# NameError: name 'hashes' is not defined

# %%
# !pip3 install semanticscholar
# !pipdeptree
# !pip3 install pyvis
# Out:
# Collecting pyvis
#   Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 7.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jinja2>=2.9.6 in /opt/conda/lib/python3.8/site-packages (from pyvis) (3.1.2)
# Collecting jsonpickle>=1.4.1
#   Downloading jsonpickle-3.0.4-py3-none-any.whl (39 kB)
# Requirement already satisfied: networkx>=1.11 in /opt/conda/lib/python3.8/site-packages (from pyvis) (2.8.7)
# Requirement already satisfied: ipython>=5.3.0 in /opt/conda/lib/python3.8/site-packages (from pyvis) (8.5.0)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (5.4.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.18.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (2.13.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (3.0.31)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.5.1)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.8/site-packages (from ipython>=5.3.0->pyvis) (4.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.8/site-packages (from jinja2>=2.9.6->pyvis) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.8/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=5.3.0->pyvis) (0.2.5)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis) (0.2.2)
# Requirement already satisfied: asttokens in /opt/conda/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis) (2.0.8)
# Requirement already satisfied: executing in /opt/conda/lib/python3.8/site-packages (from stack-data->ipython>=5.3.0->pyvis) (1.1.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from asttokens->stack-data->ipython>=5.3.0->pyvis) (1.16.0)
# Installing collected packages: jsonpickle, pyvis
# Successfully installed jsonpickle-3.0.4 pyvis-0.3.2

# %%
from semanticscholar import SemanticScholar

sch= SemanticScholar()
paper = sch.get_paper('10.1016/j.enpol.2019.01.029')
print(paper.title)
paper = sch.get_paper_references('10.1016/j.enpol.2019.01.029')
# Out:
# ---------------------------------------------------------------------------
# BadQueryParametersException               Traceback (most recent call last)
# Cell In[10], line 4
#       1 from semanticscholar import SemanticScholar
#       3 sch= SemanticScholar()
# ----> 4 paper = sch.get_paper('10.1016/j.enpol.2019.01.029')
#       5 print(paper.title)
#       6 paper = sch.get_paper_references('10.1016/j.enpol.2019.01.029')
#
# File ~/.local/lib/python3.10/site-packages/semanticscholar/SemanticScholar.py:115, in SemanticScholar.get_paper(self, paper_id, fields)
#      94 '''Paper lookup
#      95
#      96 :calls: `GET /paper/{paper_id} <https://api.semanticscholar.org/\
#    (...)
#     111 :raises: ObjectNotFoundException: if Paper ID not found.
#     112 '''
#     114 loop = asyncio.get_event_loop()
# --> 115 paper = loop.run_until_complete(
#     116     self._AsyncSemanticScholar.get_paper(
#     117         paper_id=paper_id,
#     118         fields=fields
#     119         )
#     120 )
#     122 return paper
#
# File ~/.local/lib/python3.10/site-packages/nest_asyncio.py:99, in _patch_loop.<locals>.run_until_complete(self, future)
#      96 if not f.done():
#      97     raise RuntimeError(
#      98         'Event loop stopped before Future completed.')
# ---> 99 return f.result()
#
# File /usr/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File /usr/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/.local/lib/python3.10/site-packages/semanticscholar/AsyncSemanticScholar.py:135, in AsyncSemanticScholar.get_paper(self, paper_id, fields)
#     132 fields = ','.join(fields)
#     133 parameters = f'&fields={fields}'
# --> 135 data = await self._requester.get_data_async(url, parameters, self.auth_header)
#     136 paper = Paper(data)
#     138 return paper
#
# File ~/.local/lib/python3.10/site-packages/semanticscholar/ApiRequester.py:110, in ApiRequester.get_data_async(self, url, parameters, headers, payload)
#     100 '''Get data from Semantic Scholar API
#     101
#     102 :param str url: absolute URL to API endpoint.
#    (...)
#     107 :rtype: :class:`dict` or :class:`List` of :class:`dict`
#     108 '''
#     109 if self.retry:
# --> 110     return await self._get_data_async(
#     111         url, parameters, headers, payload)
#     112 return await self._get_data_async.retry_with(
#     113         stop=stop_after_attempt(1)
#     114     )(self, url, parameters, headers, payload)
#
# File ~/.local/lib/python3.10/site-packages/tenacity/_asyncio.py:142, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#     138 @functools.wraps(
#     139     fn, functools.WRAPPER_ASSIGNMENTS + ("__defaults__", "__kwdefaults__")
#     140 )
#     141 async def async_wrapped(*args: t.Any, **kwargs: t.Any) -> t.Any:
# --> 142     return await fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/tenacity/_asyncio.py:58, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      56 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#      57 while True:
# ---> 58     do = await self.iter(retry_state=retry_state)
#      59     if isinstance(do, DoAttempt):
#      60         try:
#
# File ~/.local/lib/python3.10/site-packages/tenacity/_asyncio.py:110, in AsyncRetrying.iter(self, retry_state)
#     108 result = None
#     109 for action in self.iter_state.actions:
# --> 110     result = await action(retry_state)
#     111 return result
#
# File ~/.local/lib/python3.10/site-packages/tenacity/_asyncio.py:78, in AsyncRetrying._wrap_action_func.<locals>.inner(*args, **kwargs)
#      77 async def inner(*args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 78     return fn(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/tenacity/__init__.py:390, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     388 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     389     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 390         self._add_action_func(lambda rs: rs.outcome.result())
#     391         return
#     393     if self.after is not None:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/.local/lib/python3.10/site-packages/tenacity/_asyncio.py:61, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      59 if isinstance(do, DoAttempt):
#      60     try:
# ---> 61         result = await fn(*args, **kwargs)
#      62     except BaseException:  # noqa: B902
#      63         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.local/lib/python3.10/site-packages/semanticscholar/ApiRequester.py:147, in ApiRequester._get_data_async(self, url, parameters, headers, payload)
#     145 elif r.status_code == 400:
#     146     data = r.json()
# --> 147     raise BadQueryParametersException(data['error'])
#     148 elif r.status_code == 403:
#     149     raise PermissionError('HTTP status 403 Forbidden.')
#
# BadQueryParametersException: Unrecognized or unsupported fields: [authors.aliases]

# %%
sch = SemanticScholar()
def get_paper_authors(doi):
    paper = sch.get_paper(doi)
    return paper.title

# %%
for i, ref in enumerate(paper.items):
    #print(ref.keys())
    for author in ref['citedPaper']['authors']:
        #print(author['authorId'])
        print(i)
# Out:
# 0
# 0
# 0
# 0
# 0
# 1
# 1
# 2
# 2
# 3
# 3
# 3
# 4
# 4
# 5
# 5
# 6
# 7
# 8
# 9
# 10
# 10
# 10
# 10
# 11
# 12
# 12
# 13
# 13
# 14

# %%
"""
Skripta koja generira težinski graf iz hashtagova
te zapisuje najveću povezanu komponentu u 
"largest_cc.txt" datoteku
"""
import pandas as pd
from functions import stringlist_tolist, count_hash, remove_emoji, print_graph_info, pyvis_show
import networkx as nx
from itertools import combinations
import matplotlib.pyplot as plt
from pyvis.network import Network
import pickle
from tqdm import tqdm

N = 1000

print("Ucitavanje dataseta ...")
df = pd.read_csv("UR_6.csv", lineterminator="\n", nrows=N)
print("Dataset shape: ", df.shape)

print("Izdvajanje hashtagova ...")
df['hashtags'] = df['hashtags'].apply(stringlist_tolist)
indexer = df[df['hashtags'].apply(count_hash) >= 2]
hashes = indexer['hashtags']

print("Stvaranje grafa: ")
G = nx.Graph()
for line in tqdm(hashes):
    temp = list(combinations(set(line), 2))
    for comb in temp:
        comb = (remove_emoji(comb[0]), remove_emoji(comb[1]))
        if G.has_edge(comb[0], comb[1]):
            G[comb[0]][comb[1]]['weight'] += 1
        elif G.has_edge(comb[1], comb[0]):
            G[comb[1]][comb[0]]['weight'] += 1
        else:
            G.add_edge(comb[0], comb[1], weight=1)

largest_cc = max(nx.connected_components(G), key=len)
S = G.subgraph(largest_cc).copy()

print_graph_info(G)
print_graph_info(S)

# # Graf save
# pickle.dump(G, open('graph_pro14.pickle', 'wb'))
# pickle.dump(S, open('largest_cc_pro14.pickle', 'wb'))
# with open('largest_cc_pro14.txt', 'w') as f:
#     f.writelines(largest_cc)

print("Crtanje ...")
pyvis_show(S, True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 7
#       1 """
#       2 Skripta koja generira težinski graf iz hashtagova
#       3 te zapisuje najveću povezanu komponentu u
#       4 "largest_cc.txt" datoteku
#       5 """
#       6 import pandas as pd
# ----> 7 from functions import stringlist_tolist, count_hash, remove_emoji, print_graph_info, pyvis_show
#       8 import networkx as nx
#       9 from itertools import combinations
#
# ModuleNotFoundError: No module named 'functions'
